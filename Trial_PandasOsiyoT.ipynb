# %% [markdown]
# <a href="https://colab.research.google.com/github/ansiyo/Machine-Learning-Rep/blob/main/Trial_PandasOsiyoT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
pd.read_csv('/content/Iris.csv')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt # Import the matplotlib.pyplot module and give it the alias 'plt'
 df = pd.read_csv('/content/Iris.csv')

plt.plot(df["SepalLengthCm"], df["PetalLengthCm"])
plt.show() # Display the plot
# Out:
#   File "<ipython-input-4-affe75095667>", line 3
#     pd.read_csv('/content/Iris.csv')
#     ^
# IndentationError: unexpected indent

# %%
import pandas as pd
import matplotlib.pyplot as plt # Import the matplotlib.pyplot module and give it the alias 'plt'
df = pd.read_csv('/content/Iris.csv') # Removed extra space

plt.plot(df["SepalLengthCm"], df["PetalLengthCm"])
plt.show() # Display the plot
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-c291207d729b> in <cell line: 3>()
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt # Import the matplotlib.pyplot module and give it the alias 'plt'
# ----> 3 df = pd.read_csv('/content/Iris.csv') # Removed extra space
#       4
#       5 plt.plot(df["SepalLengthCm"], df["PetalLengthCm"])
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Make sure 'Iris.csv' is uploaded to the Colab environment
df = pd.read_csv('Iris.csv')  # Update the path if needed

plt.plot(df["SepalLengthCm"], df["PetalLengthCm"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-19abcf4e1190> in <cell line: 5>()
#       3
#       4 # Make sure 'Iris.csv' is uploaded to the Colab environment
# ----> 5 df = pd.read_csv('Iris.csv')  # Update the path if needed
#       6
#       7 plt.plot(df["SepalLengthCm"], df["PetalLengthCm"])
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Make sure 'Iris.csv' is uploaded to the Colab environment
df = pd.read_csv('/content/Iris.csv')  # Update the path if needed

plt.plot(df["SepalLengthCm"], df["SepalWidthCm"])
plt.show()

# %%
print(df.head(10))
# Out:
#    attitude  norms  control  intention  behavior
# 0      2.31   2.31     2.03       2.50      2.62
# 1      4.66   4.01     3.63       3.99      3.64
# 2      3.85   3.56     4.20       4.35      3.83
# 3      4.24   2.25     2.84       1.51      2.25
# 4      2.91   3.31     2.40       1.45      2.00
# 5      2.99   2.51     2.95       2.59      2.20
# 6      3.96   4.65     3.77       4.08      4.41
# 7      3.01   2.98     1.90       2.58      4.15
# 8      4.77   3.09     3.83       4.87      4.35
# 9      3.67   3.63     5.00       3.09      3.95

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Make sure 'Iris.csv' is uploaded to the Colab environment
df = pd.read_csv('/content/PlannedBehavior.csv')  # Update the path if needed

plt.plot(df["norms"], df["behavior"])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Make sure 'Iris.csv' is uploaded to the Colab environment
df = pd.read_csv('/content/PlannedBehavior.csv')  # Update the path if needed

plt.plot(df["attitude"], df["behavior"])
plt.show()
